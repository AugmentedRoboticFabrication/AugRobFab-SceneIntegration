# %%
import numpy as np
from src.AzureKinectParser import AzureKinectMKVParser
from src.visualizer import CameraPoseVisualizer

root = str(globals()['_dh'][0])
root
# Out:
# 'c:\\Users\\Ozguc\\Documents\\GitHub\\AugmentedRoboticFabrication'

# %%
# %matplotlib widget

poses = np.load("T_ROB\\cam2base.npy")

visualizer = CameraPoseVisualizer([0, 1500], [-500, 500], [0, 1500])

for pose in poses:
    visualizer.extrinsic2pyramid(pose, 'b', 100)
visualizer.show()
# Out:
# initialize camera pose visualizer
# c:\Users\Ozguc\Documents\GitHub\AugmentedRoboticFabrication\src\visualizer.py:10: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   self.ax = self.fig.gca(projection='3d')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
